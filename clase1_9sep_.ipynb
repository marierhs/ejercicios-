# %% [markdown]
# <a href="https://colab.research.google.com/github/marierhs/ejercicios-/blob/main/clase1_9sep_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Palabras Reservadas
#
# las palabras resservadas (keywords) corresponden a los nombres de las declaraciones que el interprete de Python incluye por defecto . no se deben utlizar dichas palabras para asignar nombres a otros objetos
#
# El listado de palabras reservadas puede ser consultado

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# EL espacio de nombres (namespace)
#
# El espacio de nombres (namespace) contiene una relacion de los objetos existentes en la memoria del sistema y los nombres a los que esta ligados

# %%
 Num1 = 10
2 print(Num1)
3 Num2 = 6
4 print(Num2)
5 Num3 = Num1 + Num2
6 print(Num3)
# Out:
#   File "/tmp/ipython-input-3010127595.py", line 1
#     1 Num1 = 10
#       ^
# SyntaxError: invalid syntax
