# %% [markdown]
# <a href="https://colab.research.google.com/github/marierhs/ejercicios-/blob/main/clase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Expresiones y comentarios
# una expresion es una combinacion de nombres ,obeto,funciones y metodos cuya sintaxis es correcta

# %% [markdown]
# ejemplo
# la s

# %%
1+1
# Out:
# 2

# %% [markdown]
# expresion si 20 es mayor   o igual 10

# %%
9 >= 10
# Out:
# False

# %% [markdown]
# metodo oper() , propio

# %%
1 "carro".upper()
# Out:
# 'CARRO'

# %% [markdown]
# funcion len()

# %%
1 len("Trecientos_______________")
# Out:
# 25

# %% [markdown]
# ejecucion de varias expresiones en una sola
#
# ejecutar multiples expresiones en una solalinea

# %% [markdown]
# ejemplo

# %%
a += 11; "amigos" * 3; a == 1;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1162796659.py in <cell line: 0>()
# ----> 1 a += 11; "amigos" * 3; a == 1;
#
# NameError: name 'a' is not defined

# %% [markdown]
# expresiones en el intorno interactivo

# %%
4 * 3
# Out:
# 12

# %%
15 >= 25
# Out:
# False

# %% [markdown]
# comentario proporciones de texto que aun cuando se encuentran dentro deun bloque de codigo no son interpretados

# %%
15 + 23 # el resultado es
# Out:
# 38

# %% [markdown]
# docstrings encerados en triples """ , son utilizados para generar     documentacion que se desplegara mediante la funcion help()

# %% [markdown]
# ejemplo

# %%
def funcion():
    """ejemplo del uso de una docstring.
    en este caso se utiliza para ducomentar la funcion"""
    print("hola")
